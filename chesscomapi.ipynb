# %% [markdown]
# Using chess.com api for games analysis

# %% [markdown]
# py -m pip install pandas
# py -m pip install chess.com

# %%
import pandas as pd
from chessdotcom import get_leaderboards, get_player_stats, get_player_game_archives
import pprint
import requests

# %%
printer = pprint.PrettyPrinter()

def print_leaderboards():
    data = get_leaderboards().json['leaderboards']['live_blitz']
    printer.pprint(data)

# %%
print_leaderboards()
# Out:
# [{'@id': 'https://api.chess.com/pub/player/nihalsarin',
#   'avatar': 'https://images.chesscomfiles.com/uploads/v1/user/7195919.0a954af9.200x200o.f25b6cb158fa.jpeg',
#   'country': 'https://api.chess.com/pub/country/FM',
#   'draw_count': 1879,
#   'flair_code': 'diamond_traditional',
#   'loss_count': 6144,
#   'name': 'Nihal Sarin',
#   'player_id': 7195919,
#   'rank': 1,
#   'score': 3211,
#   'status': 'premium',
#   'title': 'GM',
#   'trend_rank': {'delta': 0, 'direction': 0},
#   'trend_score': {'delta': 0, 'direction': 0},
#   'url': 'https://www.chess.com/member/nihalsarin',
#   'username': 'nihalsarin',
#   'win_count': 10032},
#  {'@id': 'https://api.chess.com/pub/player/hikaru',
#   'avatar': 'https://images.chesscomfiles.com/uploads/v1/user/15448422.90503d66.200x200o.f323efa57fd0.jpeg',
#   'country': 'https://api.chess.com/pub/country/US',
#   'draw_count': 2895,
#   'flair_code': 'diamond_traditional',
#   'loss_count': 3917,
#   'name': 'Hikaru Nakamura',
#   'player_id': 15448422,
#   'rank': 2,
#   'score': 3160,
#   'status': 'premium',
#   'title': 'GM',
#   'trend_rank': {'delta': 1, 'direction': 1},
#   'trend_score': {'delta': 0, 'direction': 0},
#   'url': 'https://www.chess.com/member/Hikaru',
#   'username': 'Hikaru',
#   'win_count': 23039},
#  {'@id': 'https://api.chess.com/pub/player/danielnaroditsky',
#   'avatar': 'https://images.chesscomfiles.com/uploads/v1/user/1715324.a82838d3.200x200o.26aebe95ad09.jpeg',
#   'country': 'https://api.chess.com/pub/country/US',
#   'draw_count': 3495,
#   'flair_code': 'diamond_traditional',
#   'loss_count': 9524,
#   'name': 'Daniel Naroditsky',
#   'player_id': 1715324,
#   'rank': 3,
#   'score': 3134,
#   'status': 'premium',
#   'title': 'GM',
#   'trend_rank': {'delta': 3, 'direction': 1},
#   'trend_score': {'delta': 0, 'direction': 0},
#   'url': 'https://www.chess.com/member/DanielNaroditsky',
#   'username': 'DanielNaroditsky',
#   'win_count': 18640},
#  {'@id': 'https://api.chess.com/pub/player/fairchess_on_youtube',
#   'avatar': 'https://images.chesscomfiles.com/uploads/v1/user/14498226.8202a36e.200x200o.1fe2de7e5eaa.jpeg',
#   'country': 'https://api.chess.com/pub/country/RU',
#   'draw_count': 524,
#   'flair_code': 'earth',
#   'loss_count': 719,
#   'name': 'Dmitry Andreikin',
#   'player_id': 14498226,
#   'rank': 4,
#   'score': 3128,
#   'status': 'premium',
#   'title': 'GM',
#   'trend_rank': {'delta': 5, 'direction': 1},
#   'trend_score': {'delta': 0, 'direction': 0},
#   'url': 'https://www.chess.com/member/FairChess_on_YouTube',
#   'username': 'FairChess_on_YouTube',
#   'win_count': 1977},
#  {'@id': 'https://api.chess.com/pub/player/violord',
#   'avatar': 'https://images.chesscomfiles.com/uploads/v1/user/39297886.f21b8402.200x200o.afee541d28b9.jpeg',
#   'country': 'https://api.chess.com/pub/country/MD',
#   'draw_count': 136,
#   'flair_code': 'diamond_traditional',
#   'loss_count': 534,
#   'name': 'Viorel Iordachescu',
#   'player_id': 39297886,
#   'rank': 5,
#   'score': 3115,
#   'status': 'premium',
#   'title': 'GM',
#   'trend_rank': {'delta': 5, 'direction': 1},
#   'trend_score': {'delta': 0, 'direction': 0},
#   'url': 'https://www.chess.com/member/Violord',
#   'username': 'Violord',
#   'win_count': 786},
#  {'@id': 'https://api.chess.com/pub/player/nikotheodorou',
#   'avatar': 'https://images.chesscomfiles.com/uploads/v1/user/108520120.e47c2902.200x200o.41fbee748321.jpeg',
#   'country': 'https://api.chess.com/pub/country/GR',
#   'draw_count': 239,
#   'flair_code': 'christmas_santa',
#   'loss_count': 684,
#   'name': 'Nikolas Theodorou',
#   'player_id': 108520120,
#   'rank': 6,
#   'score': 3055,
#   'status': 'premium',
#   'title': 'GM',
#   'trend_rank': {'delta': 11, 'direction': 1},
#   'trend_score': {'delta': 0, 'direction': 0},
#   'url': 'https://www.chess.com/member/NikoTheodorou',
#   'username': 'NikoTheodorou',
#   'win_count': 822},
#  {'@id': 'https://api.chess.com/pub/player/grischuk',
#   'avatar': 'https://images.chesscomfiles.com/uploads/v1/user/26897358.10f64fa8.200x200o.634d3db4ddc2.jpeg',
#   'country': 'https://api.chess.com/pub/country/RU',
#   'draw_count': 364,
#   'flair_code': 'diamond_traditional',
#   'loss_count': 429,
#   'name': 'Alexander Grischuk',
#   'player_id': 26897358,
#   'rank': 7,
#   'score': 3046,
#   'status': 'premium',
#   'title': 'GM',
#   'trend_rank': {'delta': 13, 'direction': 1},
#   'trend_score': {'delta': 0, 'direction': 0},
#   'url': 'https://www.chess.com/member/Grischuk',
#   'username': 'Grischuk',
#   'win_count': 805},
#  {'@id': 'https://api.chess.com/pub/player/bigfish1995',
#   'avatar': 'https://images.chesscomfiles.com/uploads/v1/user/26303484.26ab6957.200x200o.53640a5b7ce6.png',
#   'country': 'https://api.chess.com/pub/country/WS',
#   'draw_count': 1209,
#   'flair_code': 'diamond_gold',
#   'loss_count': 3846,
#   'name': 'Vladimir Fedoseev',
#   'player_id': 26303484,
#   'rank': 8,
#   'score': 3043,
#   'status': 'premium',
#   'title': 'GM',
#   'trend_rank': {'delta': 13, 'direction': 1},
#   'trend_score': {'delta': 0, 'direction': 0},
#   'url': 'https://www.chess.com/member/Bigfish1995',
#   'username': 'Bigfish1995',
#   'win_count': 5556},
#  {'@id': 'https://api.chess.com/pub/player/lyonbeast',
#   'avatar': 'https://images.chesscomfiles.com/uploads/v1/user/17306408.6bf914da.200x200o.8b35a64df790.jpeg',
#   'country': 'https://api.chess.com/pub/country/FR',
#   'draw_count': 297,
#   'flair_code': 'skull',
#   'loss_count': 410,
#   'name': 'Maxime Vachier-Lagrave',
#   'player_id': 17306408,
#   'rank': 9,
#   'score': 3043,
#   'status': 'premium',
#   'title': 'GM',
#   'trend_rank': {'delta': 13, 'direction': 1},
#   'trend_score': {'delta': 0, 'direction': 0},
#   'url': 'https://www.chess.com/member/LyonBeast',
#   'username': 'LyonBeast',
#   'win_count': 1183},
#  {'@id': 'https://api.chess.com/pub/player/fabianocaruana',
#   'avatar': 'https://images.chesscomfiles.com/uploads/v1/user/11177810.d53953f7.200x200o.3ef259191986.png',
#   'country': 'https://api.chess.com/pub/country/US',
#   'draw_count': 127,
#   'flair_code': 'diamond_traditional',
#   'loss_count': 229,
#   'name': 'Fabiano Caruana',
#   'player_id': 11177810,
#   'rank': 10,
#   'score': 3039,
#   'status': 'premium',
#   'title': 'GM',
#   'trend_rank': {'delta': 13, 'direction': 1},
#   'trend_score': {'delta': 0, 'direction': 0},
#   'url': 'https://www.chess.com/member/FabianoCaruana',
#   'username': 'FabianoCaruana',
#   'win_count': 691},
#  {'@id': 'https://api.chess.com/pub/player/orange_ghost',
#   'avatar': 'https://images.chesscomfiles.com/uploads/v1/user/56964058.f9920c74.200x200o.3b1426eba8c9.jpeg',
#   'country': 'https://api.chess.com/pub/country/IL',
#   'draw_count': 746,
#   'flair_code': 'troll',
#   'loss_count': 3652,
#   'name': 'Yoav Milikow',
#   'player_id': 56964058,
#   'rank': 11,
#   'score': 3037,
#   'status': 'premium',
#   'title': 'FM',
#   'trend_rank': {'delta': 13, 'direction': 1},
#   'trend_score': {'delta': 0, 'direction': 0},
#   'url': 'https://www.chess.com/member/Orange_Ghost',
#   'username': 'Orange_Ghost',
#   'win_count': 2913},
#  {'@id': 'https://api.chess.com/pub/player/oleksandr_bortnyk',
#   'avatar': 'https://images.chesscomfiles.com/uploads/v1/user/28168290.0998f38b.200x200o.c9fdc77c16cd.jpeg',
#   'country': 'https://api.chess.com/pub/country/UA',
#   'draw_count': 559,
#   'flair_code': 'earth',
#   'loss_count': 1458,
#   'name': 'Oleksandr Bortnyk',
#   'player_id': 28168290,
#   'rank': 12,
#   'score': 3036,
#   'status': 'premium',
#   'title': 'GM',
#   'trend_rank': {'delta': 14, 'direction': 1},
#   'trend_score': {'delta': 0, 'direction': 0},
#   'url': 'https://www.chess.com/member/Oleksandr_Bortnyk',
#   'username': 'Oleksandr_Bortnyk',
#   'win_count': 3980},
#  {'@id': 'https://api.chess.com/pub/player/mishanick',
#   'avatar': 'https://images.chesscomfiles.com/uploads/v1/user/17860442.d25fa08e.200x200o.81d6cc6b6581.png',
#   'country': 'https://api.chess.com/pub/country/RS',
#   'draw_count': 1439,
#   'flair_code': 'crown_blue',
#   'loss_count': 4896,
#   'name': 'Alexey Sarana',
#   'player_id': 17860442,
#   'rank': 13,
#   'score': 3030,
#   'status': 'premium',
#   'title': 'GM',
#   'trend_rank': {'delta': 15, 'direction': 1},
#   'trend_score': {'delta': 0, 'direction': 0},
#   'url': 'https://www.chess.com/member/mishanick',
#   'username': 'mishanick',
#   'win_count': 8404},
#  {'@id': 'https://api.chess.com/pub/player/konavets',
#   'avatar': 'https://images.chesscomfiles.com/uploads/v1/user/8829034.6d90a567.200x200o.60d12a06fdce.jpeg',
#   'country': 'https://api.chess.com/pub/country/US',
#   'draw_count': 515,
#   'flair_code': 'crown_orange',
#   'loss_count': 1416,
#   'name': 'Sam Sevian',
#   'player_id': 8829034,
#   'rank': 14,
#   'score': 3022,
#   'status': 'premium',
#   'title': 'GM',
#   'trend_rank': {'delta': 20, 'direction': 1},
#   'trend_score': {'delta': 0, 'direction': 0},
#   'url': 'https://www.chess.com/member/Konavets',
#   'username': 'Konavets',
#   'win_count': 2688},
#  {'@id': 'https://api.chess.com/pub/player/viditchess',
#   'avatar': 'https://images.chesscomfiles.com/uploads/v1/user/8274000.18a13248.200x200o.7611a9919a1d.jpeg',
#   'country': 'https://api.chess.com/pub/country/IN',
#   'draw_count': 233,
#   'flair_code': 'star_black',
#   'loss_count': 442,
#   'name': 'Vidit Gujrathi',
#   'player_id': 8274000,
#   'rank': 15,
#   'score': 3017,
#   'status': 'premium',
#   'title': 'GM',
#   'trend_rank': {'delta': 23, 'direction': 1},
#   'trend_score': {'delta': 0, 'direction': 0},
#   'url': 'https://www.chess.com/member/viditchess',
#   'username': 'viditchess',
#   'win_count': 958},
#  {'@id': 'https://api.chess.com/pub/player/duhless',
#   'avatar': 'https://images.chesscomfiles.com/uploads/v1/user/10174260.4865a6da.200x200o.6932fffcda21.png',
#   'country': 'https://api.chess.com/pub/country/RU',
#   'draw_count': 1033,
#   'flair_code': 'diamond_traditional',
#   'loss_count': 2410,
#   'name': 'Daniil Dubov',
#   'player_id': 10174260,
#   'rank': 16,
#   'score': 3017,
#   'status': 'premium',
#   'title': 'GM',
#   'trend_rank': {'delta': 23, 'direction': 1},
#   'trend_score': {'delta': 0, 'direction': 0},
#   'url': 'https://www.chess.com/member/Duhless',
#   'username': 'Duhless',
#   'win_count': 4461},
#  {'@id': 'https://api.chess.com/pub/player/gabuzyan_chessmood',
#   'avatar': 'https://images.chesscomfiles.com/uploads/v1/user/37044230.b43b3a72.200x200o.f1cf0f031c8d.jpeg',
#   'country': 'https://api.chess.com/pub/country/US',
#   'draw_count': 503,
#   'flair_code': 'cool',
#   'loss_count': 1634,
#   'name': 'Hovhannes Gabuzyan',
#   'player_id': 37044230,
#   'rank': 17,
#   'score': 3016,
#   'status': 'premium',
#   'title': 'GM',
#   'trend_rank': {'delta': 23, 'direction': 1},
#   'trend_score': {'delta': 0, 'direction': 0},
#   'url': 'https://www.chess.com/member/GABUZYAN_CHESSMOOD',
#   'username': 'GABUZYAN_CHESSMOOD',
#   'win_count': 1999},
#  {'@id': 'https://api.chess.com/pub/player/bogdandeac',
#   'avatar': 'https://images.chesscomfiles.com/uploads/v1/user/30887540.d858b838.200x200o.c9aa8d72d5a2.png',
#   'country': 'https://api.chess.com/pub/country/RO',
#   'draw_count': 1168,
#   'flair_code': 'diamond_traditional',
#   'loss_count': 2527,
#   'name': 'Bogdan Daniel Deac',
#   'player_id': 30887540,
#   'rank': 18,
#   'score': 3015,
#   'status': 'premium',
#   'title': 'GM',
#   'trend_rank': {'delta': 24, 'direction': 1},
#   'trend_score': {'delta': 0, 'direction': 0},
#   'url': 'https://www.chess.com/member/BogdanDeac',
#   'username': 'BogdanDeac',
#   'win_count': 4156},
#  {'@id': 'https://api.chess.com/pub/player/gmwso',
#   'avatar': 'https://images.chesscomfiles.com/uploads/v1/user/30366824.e9eb4042.200x200o.5dabd017d46f.jpeg',
#   'country': 'https://api.chess.com/pub/country/US',
#   'draw_count': 344,
#   'flair_code': 'diamond_traditional',
#   'loss_count': 469,
#   'name': 'Wesley So',
#   'player_id': 30366824,
#   'rank': 19,
#   'score': 3015,
#   'status': 'premium',
#   'title': 'GM',
#   'trend_rank': {'delta': 24, 'direction': 1},
#   'trend_score': {'delta': 0, 'direction': 0},
#   'url': 'https://www.chess.com/member/GMWSO',
#   'username': 'GMWSO',
#   'win_count': 901},
#  {'@id': 'https://api.chess.com/pub/player/panoramix64',
#   'avatar': 'https://www.chess.com/bundles/web/images/noavatar_l.84a92436.gif',
#   'country': 'https://api.chess.com/pub/country/MX',
#   'draw_count': 22,
#   'flair_code': 'nothing',
#   'loss_count': 62,
#   'player_id': 172886269,
#   'rank': 20,
#   'score': 3015,
#   'status': 'basic',
#   'trend_rank': {'delta': 24, 'direction': 1},
#   'trend_score': {'delta': 0, 'direction': 0},
#   'url': 'https://www.chess.com/member/panoramix64',
#   'username': 'panoramix64',
#   'win_count': 224},
#  {'@id': 'https://api.chess.com/pub/player/jefferyx',
#   'avatar': 'https://images.chesscomfiles.com/uploads/v1/user/11474230.1802ddb7.200x200o.60d5d5608100.jpeg',
#   'country': 'https://api.chess.com/pub/country/US',
#   'draw_count': 320,
#   'flair_code': 'diamond_traditional',
#   'loss_count': 367,
#   'name': 'Jeffery Xiong',
#   'player_id': 11474230,
#   'rank': 21,
#   'score': 3015,
#   'status': 'premium',
#   'title': 'GM',
#   'trend_rank': {'delta': 24, 'direction': 1},
#   'trend_score': {'delta': 0, 'direction': 0},
#   'url': 'https://www.chess.com/member/jefferyx',
#   'username': 'jefferyx',
#   'win_count': 1172},
#  {'@id': 'https://api.chess.com/pub/player/baku_boulevard',
#   'avatar': 'https://images.chesscomfiles.com/uploads/v1/user/137706882.0ca988e2.200x200o.e0649ae91b4c.jpeg',
#   'country': 'https://api.chess.com/pub/country/UA',
#   'draw_count': 113,
#   'flair_code': 'diamond_traditional',
#   'loss_count': 261,
#   'name': 'Rauf Mamedov',
#   'player_id': 137706882,
#   'rank': 22,
#   'score': 3011,
#   'status': 'premium',
#   'title': 'GM',
#   'trend_rank': {'delta': 25, 'direction': 1},
#   'trend_score': {'delta': 0, 'direction': 0},
#   'url': 'https://www.chess.com/member/Baku_Boulevard',
#   'username': 'Baku_Boulevard',
#   'win_count': 490},
#  {'@id': 'https://api.chess.com/pub/player/ghandeevam2003',
#   'avatar': 'https://images.chesscomfiles.com/uploads/v1/user/20718020.b93b0dad.200x200o.ce63c2b5ea24.jpeg',
#   'country': 'https://api.chess.com/pub/country/IN',
#   'draw_count': 785,
#   'flair_code': 'battle',
#   'loss_count': 2427,
#   'name': 'Arjun Erigaisi',
#   'player_id': 20718020,
#   'rank': 23,
#   'score': 3005,
#   'status': 'premium',
#   'title': 'GM',
#   'trend_rank': {'delta': 31, 'direction': 1},
#   'trend_score': {'delta': 0, 'direction': 0},
#   'url': 'https://www.chess.com/member/GHANDEEVAM2003',
#   'username': 'GHANDEEVAM2003',
#   'win_count': 3483},
#  {'@id': 'https://api.chess.com/pub/player/elefante38',
#   'avatar': 'https://www.chess.com/bundles/web/images/noavatar_l.84a92436.gif',
#   'country': 'https://api.chess.com/pub/country/BR',
#   'draw_count': 374,
#   'flair_code': 'diamond_traditional',
#   'loss_count': 1453,
#   'player_id': 63141238,
#   'rank': 24,
#   'score': 3001,
#   'status': 'premium',
#   'title': 'GM',
#   'trend_rank': {'delta': 38, 'direction': 1},
#   'trend_score': {'delta': 0, 'direction': 0},
#   'url': 'https://www.chess.com/member/elefante38',
#   'username': 'elefante38',
#   'win_count': 1676},
#  {'@id': 'https://api.chess.com/pub/player/blitzking96',
#   'avatar': 'https://images.chesscomfiles.com/uploads/v1/user/134496332.d1b4f3e2.200x200o.74f66f78c32d.jpeg',
#   'country': 'https://api.chess.com/pub/country/US',
#   'draw_count': 15,
#   'flair_code': 'nothing',
#   'loss_count': 23,
#   'name': 'Authorized Speed Run account of GM Oleksandr Bortnyk',
#   'player_id': 134496332,
#   'rank': 25,
#   'score': 3001,
#   'status': 'basic',
#   'trend_rank': {'delta': 39, 'direction': 1},
#   'trend_score': {'delta': 0, 'direction': 0},
#   'url': 'https://www.chess.com/member/BlitzKing96',
#   'username': 'BlitzKing96',
#   'win_count': 318},
#  {'@id': 'https://api.chess.com/pub/player/0gzpanda',
#   'avatar': 'https://images.chesscomfiles.com/uploads/v1/user/73320100.6c8e4f24.200x200o.f9f3d478a069.jpeg',
#   'country': 'https://api.chess.com/pub/country/US',
#   'draw_count': 188,
#   'flair_code': 'fury',
#   'loss_count': 689,
#   'player_id': 73320100,
#   'rank': 26,
#   'score': 3000,
#   'status': 'premium',
#   'title': 'IM',
#   'trend_rank': {'delta': 40, 'direction': 1},
#   'trend_score': {'delta': 0, 'direction': 0},
#   'url': 'https://www.chess.com/member/0gZPanda',
#   'username': '0gZPanda',
#   'win_count': 1000},
#  {'@id': 'https://api.chess.com/pub/player/gm_dmitrij',
#   'avatar': 'https://images.chesscomfiles.com/uploads/v1/user/27181148.59e377d4.200x200o.e1501882ef88.jpeg',
#   'country': 'https://api.chess.com/pub/country/DE',
#   'draw_count': 2537,
#   'flair_code': 'diamond_traditional',
#   'loss_count': 8631,
#   'name': 'Dmitrij Kollars',
#   'player_id': 27181148,
#   'rank': 27,
#   'score': 2994,
#   'status': 'premium',
#   'title': 'GM',
#   'trend_rank': {'delta': 49, 'direction': 1},
#   'trend_score': {'delta': 0, 'direction': 0},
#   'url': 'https://www.chess.com/member/GM_dmitrij',
#   'username': 'GM_dmitrij',
#   'win_count': 12740},
#  {'@id': 'https://api.chess.com/pub/player/liemle',
#   'avatar': 'https://images.chesscomfiles.com/uploads/v1/user/13579258.d450eea1.200x200o.c0ae4730150d.jpeg',
#   'country': 'https://api.chess.com/pub/country/VN',
#   'draw_count': 245,
#   'flair_code': 'diamond_traditional',
#   'loss_count': 403,
#   'name': 'Liem Le',
#   'player_id': 13579258,
#   'rank': 28,
#   'score': 2994,
#   'status': 'premium',
#   'title': 'GM',
#   'trend_rank': {'delta': 49, 'direction': 1},
#   'trend_score': {'delta': 0, 'direction': 0},
#   'url': 'https://www.chess.com/member/LiemLe',
#   'username': 'LiemLe',
#   'win_count': 866},
#  {'@id': 'https://api.chess.com/pub/player/champ2005',
#   'avatar': 'https://images.chesscomfiles.com/uploads/v1/user/28667108.aa7d6253.200x200o.c70a46ed8447.jpeg',
#   'country': 'https://api.chess.com/pub/country/IN',
#   'draw_count': 1311,
#   'flair_code': 'thumbs_up',
#   'loss_count': 2943,
#   'name': 'Raunak Sadhwani',
#   'player_id': 28667108,
#   'rank': 29,
#   'score': 2993,
#   'status': 'premium',
#   'title': 'GM',
#   'trend_rank': {'delta': 49, 'direction': 1},
#   'trend_score': {'delta': 0, 'direction': 0},
#   'url': 'https://www.chess.com/member/champ2005',
#   'username': 'champ2005',
#   'win_count': 3870},
#  {'@id': 'https://api.chess.com/pub/player/salem-ar',
#   'avatar': 'https://images.chesscomfiles.com/uploads/v1/user/27168196.4c1ff3d9.200x200o.e7f139ecd010.jpeg',
#   'country': 'https://api.chess.com/pub/country/AE',
#   'draw_count': 735,
#   'flair_code': 'marshall',
#   'loss_count': 2827,
#   'name': 'Salem AR Saleh',
#   'player_id': 27168196,
#   'rank': 30,
#   'score': 2992,
#   'status': 'premium',
#   'title': 'GM',
#   'trend_rank': {'delta': 49, 'direction': 1},
#   'trend_score': {'delta': 0, 'direction': 0},
#   'url': 'https://www.chess.com/member/Salem-AR',
#   'username': 'Salem-AR',
#   'win_count': 3949},
#  {'@id': 'https://api.chess.com/pub/player/rightarmoftheforbiddenone',
#   'avatar': 'https://images.chesscomfiles.com/uploads/v1/user/163789503.e9dd1f48.200x200o.c2b6d572fa51.jpeg',
#   'country': 'https://api.chess.com/pub/country/EG',
#   'draw_count': 16,
#   'flair_code': 'diamond_traditional',
#   'loss_count': 79,
#   'player_id': 163789503,
#   'rank': 31,
#   'score': 2992,
#   'status': 'premium',
#   'title': 'GM',
#   'trend_rank': {'delta': 49, 'direction': 1},
#   'trend_score': {'delta': 0, 'direction': 0},
#   'url': 'https://www.chess.com/member/RightArmOfTheForbiddenOne',
#   'username': 'RightArmOfTheForbiddenOne',
#   'win_count': 89},
#  {'@id': 'https://api.chess.com/pub/player/gmvallejo',
#   'avatar': 'https://www.chess.com/bundles/web/images/noavatar_l.84a92436.gif',
#   'country': 'https://api.chess.com/pub/country/ES',
#   'draw_count': 94,
#   'flair_code': 'diamond_traditional',
#   'loss_count': 161,
#   'name': 'Francisco Vallejo Pons',
#   'player_id': 3164022,
#   'rank': 32,
#   'score': 2988,
#   'status': 'premium',
#   'title': 'GM',
#   'trend_rank': {'delta': 53, 'direction': 1},
#   'trend_score': {'delta': 0, 'direction': 0},
#   'url': 'https://www.chess.com/member/GMVallejo',
#   'username': 'GMVallejo',
#   'win_count': 440},
#  {'@id': 'https://api.chess.com/pub/player/dropstonedp',
#   'avatar': 'https://images.chesscomfiles.com/uploads/v1/user/69192934.19df0418.200x200o.5839b2717eb5.jpeg',
#   'country': 'https://api.chess.com/pub/country/RU',
#   'draw_count': 1069,
#   'flair_code': 'white_pawn',
#   'loss_count': 2163,
#   'name': 'David Paravyan',
#   'player_id': 69192934,
#   'rank': 33,
#   'score': 2986,
#   'status': 'premium',
#   'title': 'GM',
#   'trend_rank': {'delta': 55, 'direction': 1},
#   'trend_score': {'delta': 0, 'direction': 0},
#   'url': 'https://www.chess.com/member/dropstoneDP',
#   'username': 'dropstoneDP',
#   'win_count': 3335},
#  {'@id': 'https://api.chess.com/pub/player/jospem',
#   'avatar': 'https://images.chesscomfiles.com/uploads/v1/user/26867272.87be9fe5.200x200o.10e05ede6f58.jpeg',
#   'country': 'https://api.chess.com/pub/country/PE',
#   'draw_count': 1763,
#   'flair_code': 'crown_red',
#   'loss_count': 5411,
#   'name': 'Jose Eduardo Martinez Alcantara',
#   'player_id': 26867272,
#   'rank': 34,
#   'score': 2984,
#   'status': 'premium',
#   'title': 'GM',
#   'trend_rank': {'delta': 57, 'direction': 1},
#   'trend_score': {'delta': 0, 'direction': 0},
#   'url': 'https://www.chess.com/member/Jospem',
#   'username': 'Jospem',
#   'win_count': 11905},
#  {'@id': 'https://api.chess.com/pub/player/christopheryoo',
#   'avatar': 'https://images.chesscomfiles.com/uploads/v1/user/14074142.1fe9a37b.200x200o.2ba9552e046f.jpeg',
#   'country': 'https://api.chess.com/pub/country/ST',
#   'draw_count': 866,
#   'flair_code': 'smile',
#   'loss_count': 2286,
#   'name': 'Christopher Woojin Yoo',
#   'player_id': 14074142,
#   'rank': 35,
#   'score': 2983,
#   'status': 'premium',
#   'title': 'GM',
#   'trend_rank': {'delta': 58, 'direction': 1},
#   'trend_score': {'delta': 0, 'direction': 0},
#   'url': 'https://www.chess.com/member/ChristopherYoo',
#   'username': 'ChristopherYoo',
#   'win_count': 4610},
#  {'@id': 'https://api.chess.com/pub/player/oparingrigoriy',
#   'avatar': 'https://images.chesscomfiles.com/uploads/v1/user/3952699.32551ce3.200x200o.ff1c21155ff0.jpeg',
#   'country': 'https://api.chess.com/pub/country/US',
#   'draw_count': 859,
#   'flair_code': 'diamond_traditional',
#   'loss_count': 1551,
#   'name': 'Grigoriy Oparin',
#   'player_id': 3952699,
#   'rank': 36,
#   'score': 2979,
#   'status': 'premium',
#   'title': 'GM',
#   'trend_rank': {'delta': 59, 'direction': 1},
#   'trend_score': {'delta': 0, 'direction': 0},
#   'url': 'https://www.chess.com/member/OparinGrigoriy',
#   'username': 'OparinGrigoriy',
#   'win_count': 3473},
#  {'@id': 'https://api.chess.com/pub/player/denlaz',
#   'avatar': 'https://images.chesscomfiles.com/uploads/v1/user/34145346.09633abd.200x200o.3aa87a0b6167.jpeg',
#   'country': 'https://api.chess.com/pub/country/BY',
#   'draw_count': 347,
#   'flair_code': 'diamond_traditional',
#   'loss_count': 781,
#   'name': 'Denis Lazavik',
#   'player_id': 34145346,
#   'rank': 37,
#   'score': 2979,
#   'status': 'premium',
#   'title': 'IM',
#   'trend_rank': {'delta': 59, 'direction': 1},
#   'trend_score': {'delta': 0, 'direction': 0},
#   'url': 'https://www.chess.com/member/DenLaz',
#   'username': 'DenLaz',
#   'win_count': 1371},
#  {'@id': 'https://api.chess.com/pub/player/andreikka',
#   'avatar': 'https://images.chesscomfiles.com/uploads/v1/user/10767030.e0825f66.200x200o.7e9a1d92598d.jpeg',
#   'country': 'https://api.chess.com/pub/country/RU',
#   'draw_count': 363,
#   'flair_code': 'komodo',
#   'loss_count': 1076,
#   'name': 'Andrey Esipenko',
#   'player_id': 10767030,
#   'rank': 38,
#   'score': 2979,
#   'status': 'premium',
#   'title': 'GM',
#   'trend_rank': {'delta': 59, 'direction': 1},
#   'trend_score': {'delta': 0, 'direction': 0},
#   'url': 'https://www.chess.com/member/Andreikka',
#   'username': 'Andreikka',
#   'win_count': 1498},
#  {'@id': 'https://api.chess.com/pub/player/nyzhnyk_illia',
#   'avatar': 'https://images.chesscomfiles.com/uploads/v1/user/4863119.8ab43873.200x200o.ee142d359d67.jpeg',
#   'country': 'https://api.chess.com/pub/country/US',
#   'draw_count': 107,
#   'flair_code': 'diamond_traditional',
#   'loss_count': 173,
#   'name': 'Illia Nyzhnyk',
#   'player_id': 4863119,
#   'rank': 39,
#   'score': 2978,
#   'status': 'premium',
#   'title': 'GM',
#   'trend_rank': {'delta': 59, 'direction': 1},
#   'trend_score': {'delta': 0, 'direction': 0},
#   'url': 'https://www.chess.com/member/Nyzhnyk_Illia',
#   'username': 'Nyzhnyk_Illia',
#   'win_count': 937},
#  {'@id': 'https://api.chess.com/pub/player/wonderfultime',
#   'avatar': 'https://images.chesscomfiles.com/uploads/v1/user/16938404.f8d90ca0.200x200o.8da70d36ef33.jpeg',
#   'country': 'https://api.chess.com/pub/country/VN',
#   'draw_count': 1549,
#   'flair_code': 'crown_rainbow',
#   'loss_count': 4616,
#   'name': 'Tuan Minh Le',
#   'player_id': 16938404,
#   'rank': 40,
#   'score': 2978,
#   'status': 'premium',
#   'title': 'IM',
#   'trend_rank': {'delta': 60, 'direction': 1},
#   'trend_score': {'delta': 0, 'direction': 0},
#   'url': 'https://www.chess.com/member/wonderfultime',
#   'username': 'wonderfultime',
#   'win_count': 9069},
#  {'@id': 'https://api.chess.com/pub/player/formerprodigy',
#   'avatar': 'https://images.chesscomfiles.com/uploads/v1/user/52897514.bafc27e4.200x200o.87ad50d26944.jpeg',
#   'country': 'https://api.chess.com/pub/country/CZ',
#   'draw_count': 107,
#   'flair_code': 'flag_ukraine',
#   'loss_count': 248,
#   'name': 'David Navara',
#   'player_id': 52897514,
#   'rank': 41,
#   'score': 2975,
#   'status': 'premium',
#   'title': 'GM',
#   'trend_rank': {'delta': 62, 'direction': 1},
#   'trend_score': {'delta': 0, 'direction': 0},
#   'url': 'https://www.chess.com/member/FormerProdigy',
#   'username': 'FormerProdigy',
#   'win_count': 520},
#  {'@id': 'https://api.chess.com/pub/player/azerichess',
#   'avatar': 'https://images.chesscomfiles.com/uploads/v1/user/47865732.2ed84ac2.200x200o.8d99198ff5dd.jpeg',
#   'country': 'https://api.chess.com/pub/country/AZ',
#   'draw_count': 191,
#   'flair_code': 'diamond_traditional',
#   'loss_count': 442,
#   'name': 'Shakhriyar Mamedyarov',
#   'player_id': 47865732,
#   'rank': 42,
#   'score': 2973,
#   'status': 'premium',
#   'title': 'GM',
#   'trend_rank': {'delta': 63, 'direction': 1},
#   'trend_score': {'delta': 0, 'direction': 0},
#   'url': 'https://www.chess.com/member/Azerichess',
#   'username': 'Azerichess',
#   'win_count': 740},
#  {'@id': 'https://api.chess.com/pub/player/aryantari',
#   'avatar': 'https://images.chesscomfiles.com/uploads/v1/user/7684272.efbe0b3b.200x200o.b088a3af8b69.jpeg',
#   'country': 'https://api.chess.com/pub/country/NO',
#   'draw_count': 505,
#   'flair_code': 'diamond_traditional',
#   'loss_count': 1950,
#   'name': 'Aryan Tari',
#   'player_id': 7684272,
#   'rank': 43,
#   'score': 2969,
#   'status': 'premium',
#   'title': 'GM',
#   'trend_rank': {'delta': 64, 'direction': 1},
#   'trend_score': {'delta': 0, 'direction': 0},
#   'url': 'https://www.chess.com/member/AryanTari',
#   'username': 'AryanTari',
#   'win_count': 3002},
#  {'@id': 'https://api.chess.com/pub/player/zkid',
#   'avatar': 'https://images.chesscomfiles.com/uploads/v1/user/1984522.c5e9aa58.200x200o.9f2da001c07c.jpeg',
#   'country': 'https://api.chess.com/pub/country/US',
#   'draw_count': 162,
#   'flair_code': 'flag_ukraine',
#   'loss_count': 509,
#   'name': 'Steven Zierk',
#   'player_id': 1984522,
#   'rank': 44,
#   'score': 2969,
#   'status': 'premium',
#   'title': 'GM',
#   'trend_rank': {'delta': 65, 'direction': 1},
#   'trend_score': {'delta': 0, 'direction': 0},
#   'url': 'https://www.chess.com/member/Zkid',
#   'username': 'Zkid',
#   'win_count': 1008},
#  {'@id': 'https://api.chess.com/pub/player/indianlad',
#   'avatar': 'https://images.chesscomfiles.com/uploads/v1/user/6412751.202b53d4.200x200o.22e08c6a1173.jpeg',
#   'country': 'https://api.chess.com/pub/country/IN',
#   'draw_count': 1465,
#   'flair_code': 'diamond_traditional',
#   'loss_count': 4416,
#   'name': 'S.L. Narayanan',
#   'player_id': 6412751,
#   'rank': 45,
#   'score': 2968,
#   'status': 'premium',
#   'title': 'GM',
#   'trend_rank': {'delta': 65, 'direction': 1},
#   'trend_score': {'delta': 0, 'direction': 0},
#   'url': 'https://www.chess.com/member/Indianlad',
#   'username': 'Indianlad',
#   'win_count': 6379},
#  {'@id': 'https://api.chess.com/pub/player/kirillshevchenko',
#   'avatar': 'https://images.chesscomfiles.com/uploads/v1/user/29384074.b35155c2.200x200o.319d84a30fab.jpeg',
#   'country': 'https://api.chess.com/pub/country/UA',
#   'draw_count': 293,
#   'flair_code': 'flag_ukraine',
#   'loss_count': 748,
#   'name': 'Kirill Shevchenko',
#   'player_id': 29384074,
#   'rank': 46,
#   'score': 2966,
#   'status': 'premium',
#   'title': 'GM',
#   'trend_rank': {'delta': 66, 'direction': 1},
#   'trend_score': {'delta': 0, 'direction': 0},
#   'url': 'https://www.chess.com/member/kirillshevchenko',
#   'username': 'kirillshevchenko',
#   'win_count': 1222},
#  {'@id': 'https://api.chess.com/pub/player/zhalmakhanov_ramazan',
#   'avatar': 'https://www.chess.com/bundles/web/images/noavatar_l.84a92436.gif',
#   'country': 'https://api.chess.com/pub/country/KZ',
#   'draw_count': 9,
#   'flair_code': 'diamond_traditional',
#   'loss_count': 30,
#   'name': 'Ramazan Zhalmakhanov',
#   'player_id': 79873890,
#   'rank': 47,
#   'score': 2958,
#   'status': 'premium',
#   'title': 'FM',
#   'trend_rank': {'delta': 76, 'direction': 1},
#   'trend_score': {'delta': 0, 'direction': 0},
#   'url': 'https://www.chess.com/member/Zhalmakhanov_Ramazan',
#   'username': 'Zhalmakhanov_Ramazan',
#   'win_count': 70},
#  {'@id': 'https://api.chess.com/pub/player/artooooo',
#   'avatar': 'https://www.chess.com/bundles/web/images/noavatar_l.84a92436.gif',
#   'country': 'https://api.chess.com/pub/country/AM',
#   'draw_count': 433,
#   'flair_code': 'diamond_traditional',
#   'loss_count': 3097,
#   'name': 'Artavazd Hayrapetyan',
#   'player_id': 14995614,
#   'rank': 48,
#   'score': 2958,
#   'status': 'premium',
#   'title': 'FM',
#   'trend_rank': {'delta': 76, 'direction': 1},
#   'trend_score': {'delta': 0, 'direction': 0},
#   'url': 'https://www.chess.com/member/Artooooo',
#   'username': 'Artooooo',
#   'win_count': 5354},
#  {'@id': 'https://api.chess.com/pub/player/comeback_2019',
#   'avatar': 'https://www.chess.com/bundles/web/images/noavatar_l.84a92436.gif',
#   'country': 'https://api.chess.com/pub/country/RU',
#   'draw_count': 77,
#   'flair_code': 'nothing',
#   'loss_count': 305,
#   'player_id': 65886284,
#   'rank': 49,
#   'score': 2957,
#   'status': 'basic',
#   'trend_rank': {'delta': 76, 'direction': 1},
#   'trend_score': {'delta': 0, 'direction': 0},
#   'url': 'https://www.chess.com/member/Comeback_2019',
#   'username': 'Comeback_2019',
#   'win_count': 527},
#  {'@id': 'https://api.chess.com/pub/player/miterryble',
#   'avatar': 'https://images.chesscomfiles.com/uploads/v1/user/21261922.c6032310.200x200o.20fdb63b0854.jpeg',
#   'country': 'https://api.chess.com/pub/country/PE',
#   'draw_count': 1258,
#   'flair_code': 'diamond_traditional',
#   'loss_count': 1713,
#   'name': 'Renato Terry',
#   'player_id': 21261922,
#   'rank': 50,
#   'score': 2956,
#   'status': 'premium',
#   'title': 'IM',
#   'trend_rank': {'delta': 79, 'direction': 1},
#   'trend_score': {'delta': 0, 'direction': 0},
#   'url': 'https://www.chess.com/member/MITerryble',
#   'username': 'MITerryble',
#   'win_count': 7680}]

# %% [markdown]
# Getting my personal stats :)

# %%
data = get_player_stats('ADeny89').json['stats']
printer.pprint(data)
# Out:
# {'chess_blitz': {'best': {'date': 1638723467,
#                           'game': 'https://www.chess.com/game/live/15625961209',
#                           'rating': 1183},
#                  'last': {'date': 1657899251, 'rating': 1059, 'rd': 45},
#                  'record': {'draw': 20, 'loss': 304, 'win': 318}},
#  'chess_bullet': {'best': {'date': 1636191619,
#                            'game': 'https://www.chess.com/game/live/29930330299',
#                            'rating': 1227},
#                   'last': {'date': 1657460179, 'rating': 932, 'rd': 161},
#                   'record': {'draw': 0, 'loss': 3, 'win': 2}},
#  'chess_rapid': {'best': {'date': 1616174568,
#                           'game': 'https://www.chess.com/game/live/9984163825',
#                           'rating': 1446},
#                  'last': {'date': 1629813245, 'rating': 1351, 'rd': 69},
#                  'record': {'draw': 12, 'loss': 105, 'win': 124}},
#  'fide': 0,
#  'lessons': {},
#  'puzzle_rush': {'best': {'score': 7, 'total_attempts': 10}},
#  'tactics': {'highest': {'date': 1656838245, 'rating': 1856},
#              'lowest': {'date': 1575234631, 'rating': 390}}}

# %%
def get_player_rating(username):
    data = get_player_stats(username).json['stats']
    categories = ['chess_blitz', 'chess_rapid', 'chess_bullet']
    for category in categories:
        print('Category:', category)
        print(f'Current: {data[category]["last"]["rating"]}')
        print(f'Best: {data[category]["best"]["rating"]}')
        print(f'Best: {data[category]["record"]}')

# %%
get_player_rating('ADeny89')
# Out:
# Category: chess_blitz
# Current: 1059
# Best: 1183
# Best: {'win': 318, 'loss': 304, 'draw': 20}
# Category: chess_rapid
# Current: 1351
# Best: 1446
# Best: {'win': 124, 'loss': 105, 'draw': 12}
# Category: chess_bullet
# Current: 932
# Best: 1227
# Best: {'win': 2, 'loss': 3, 'draw': 0}

# %% [markdown]
# Get Games Information

# %%
def get_most_recent_game(username):
    data = get_player_game_archives(username).json
    url = data['archives'][-1]
    games = requests.get(url).json()
    game = games['games'][-1]
    printer.pprint(game)

# %%
get_most_recent_game('ADeny89')
# Out:
# {'accuracies': {'black': 58.39, 'white': 65.42},
#  'black': {'@id': 'https://api.chess.com/pub/player/johnnoyes',
#            'rating': 1052,
#            'result': 'resigned',
#            'username': 'JohnNoyes',
#            'uuid': 'ed524c18-c6d9-11e6-8036-000000000000'},
#  'end_time': 1657899251,
#  'fen': '2r3k1/pp1R1p1p/5Bp1/5n2/8/8/P1P2P1P/R6K b - -',
#  'initial_setup': 'rnbqkbnr/pppppppp/8/8/8/8/PPPPPPPP/RNBQKBNR w KQkq - 0 1',
#  'pgn': '[Event "Live Chess"]\n'
#         '[Site "Chess.com"]\n'
#         '[Date "2022.07.15"]\n'
#         '[Round "-"]\n'
#         '[White "ADeny89"]\n'
#         '[Black "JohnNoyes"]\n'
#         '[Result "1-0"]\n'
#         '[CurrentPosition "2r3k1/pp1R1p1p/5Bp1/5n2/8/8/P1P2P1P/R6K b - -"]\n'
#         '[Timezone "UTC"]\n'
#         '[ECO "B00"]\n'
#         '[ECOUrl '
#         '"https://www.chess.com/openings/Nimzowitsch-Defense-Mikenas-Variation"]\n'
#         '[UTCDate "2022.07.15"]\n'
#         '[UTCTime "15:27:03"]\n'
#         '[WhiteElo "1059"]\n'
#         '[BlackElo "1052"]\n'
#         '[TimeControl "300+5"]\n'
#         '[Termination "ADeny89 won by resignation"]\n'
#         '[StartTime "15:27:03"]\n'
#         '[EndDate "2022.07.15"]\n'
#         '[EndTime "15:34:11"]\n'
#         '[Link "https://www.chess.com/game/live/51637817329"]\n'
#         '\n'
#         '1. e4 {[%clk 0:05:01.8]} 1... d6 {[%clk 0:05:03.5]} 2. d4 {[%clk '
#         '0:05:05.1]} 2... Nc6 {[%clk 0:05:07.9]} 3. Nf3 {[%clk 0:05:07.9]} '
#         '3... Nf6 {[%clk 0:05:08.4]} 4. Nc3 {[%clk 0:05:10.3]} 4... g6 {[%clk '
#         '0:05:12.4]} 5. Bb5 {[%clk 0:05:12.5]} 5... Bd7 {[%clk 0:05:14.6]} 6. '
#         'e5 {[%clk 0:05:02.8]} 6... dxe5 {[%clk 0:05:18.4]} 7. dxe5 {[%clk '
#         '0:05:06.2]} 7... Ng4 {[%clk 0:05:17.1]} 8. Bxc6 {[%clk 0:05:01.6]} '
#         '8... Bxc6 {[%clk 0:05:18.2]} 9. O-O {[%clk 0:04:57.5]} 9... Qxd1 '
#         '{[%clk 0:05:16.8]} 10. Rxd1 {[%clk 0:04:58.3]} 10... Bxf3 {[%clk '
#         '0:05:20]} 11. gxf3 {[%clk 0:04:58.6]} 11... Nxe5 {[%clk 0:05:23.4]} '
#         '12. Bf4 {[%clk 0:04:40.1]} 12... Nxf3+ {[%clk 0:05:20.9]} 13. Kg2 '
#         '{[%clk 0:04:42.6]} 13... Nh4+ {[%clk 0:05:20.5]} 14. Kh1 {[%clk '
#         '0:04:41.8]} 14... Bg7 {[%clk 0:05:11.3]} 15. Nd5 {[%clk 0:04:34.4]} '
#         '15... O-O {[%clk 0:05:00.7]} 16. Nxe7+ {[%clk 0:04:34.5]} 16... Kh8 '
#         '{[%clk 0:04:58.3]} 17. Bxc7 {[%clk 0:04:28.9]} 17... Rac8 {[%clk '
#         '0:04:36.7]} 18. Bg3 {[%clk 0:04:26.7]} 18... Rce8 {[%clk 0:04:19.1]} '
#         '19. Nd5 {[%clk 0:04:17.1]} 19... Nf5 {[%clk 0:04:17.5]} 20. Nc3 '
#         '{[%clk 0:03:29.1]} 20... Bxc3 {[%clk 0:04:17.8]} 21. bxc3 {[%clk '
#         '0:03:21.6]} 21... Rc8 {[%clk 0:04:21.4]} 22. Be5+ {[%clk 0:03:21.9]} '
#         '22... Kg8 {[%clk 0:04:24]} 23. Rd7 {[%clk 0:03:24.9]} 23... Rxc3 '
#         '{[%clk 0:04:12.6]} 24. Bxc3 {[%clk 0:03:07.1]} 24... Rc8 {[%clk '
#         '0:04:16.3]} 25. Bf6 {[%clk 0:02:59.6]} 1-0\n',
#  'rated': True,
#  'rules': 'chess',
#  'tcn': 'mCZRlB5Qgv!Tbs2UfH6ZCKRKBKTEHQZQeg7dfdQvovEKcDKvgovFoh92sJ8!J0!?DY46Yw680JFLJs2sjs86wK?!dZ6sKs96sT',
#  'time_class': 'blitz',
#  'time_control': '300+5',
#  'url': 'https://www.chess.com/game/live/51637817329',
#  'uuid': '8d8f2046-0452-11ed-9be9-78ac4409ff3c',
#  'white': {'@id': 'https://api.chess.com/pub/player/adeny89',
#            'rating': 1059,
#            'result': 'win',
#            'username': 'ADeny89',
#            'uuid': 'cf775b2a-147e-11ea-8bc9-efc2a6e812ee'}}
